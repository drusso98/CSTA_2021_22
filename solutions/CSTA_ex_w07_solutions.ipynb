# %% [markdown]
# # Ex 1
#
# In the previous weeks you have seen how to tokenize a text using regular expressions, and how to get useful information, such as lemmas and POS, using already tagged knowledge bases. In the last lesson, you were introduced to the use of existing tools that provide an efficient and intuitive pipeline for obtaining the same information with just a few lines of code. One such tool is Stanza.
#
# Let's put the pieces together and try to build useful functions for processing text with Stanza. After importing Stanza correctly, choose a language you want to work with (you can see the supported languages <a href="https://stanfordnlp.github.io/stanza/available_models.html"> here</a>) and download the appropriate model. Then write two functions. The first will take as argument the path to a text file written in the language of your choice (you can download it from Gutenberg or use one of your choice). The function must save the result of the Stanza pipeline (the input of which will be the last 10000 characters of your text) as a JSON file and return the corresponding dictionary. The second function is a variation of the <i>json_to_tokens(...)</i> function already written in class. Modify it so that it also returns a dictionary whose keys will be the tokens and the related values will consist of a dictionary with the following information: lemma, upos, feats.

# %%
def json_to_tokens(path_, keys = ["text"] ):
    out = []  
    jin = json.load(open(path_))
    for sent in jin:
        temps = [] 
    for word in sent:
        tword = []
        for key in keys: 
            try:
                tword.append(word[key])
            except KeyError:
                pass
        temps.append(tword) 
    out.append(temps) 
return out

# %%
! pip install stanza

import stanza
import json
# dowloading the English model 
# stanza.download("en")



def stanza_to_json(path):
    
    # opneing my text file
    text = open(path, "r", encoding = "utf-8-sig")
    text = text.read()
    
    # initializing Stanza Pipeline
    nlp = stanza.Pipeline("en")
    
    # feeding the Pipeline with the last 10000 chars of my text
    processed_doc = nlp(text[:-10000])
    processed_doc_dict = processed_doc.to_dict()
    
    # saving the dict in a .json file
    with open("/content/drive/MyDrive/CSTA/processed_doc.json", "w", encoding="utf-8-sig") as fout:
        json.dump(processed_doc_dict, fout)
        
    return processed_doc_dict


def json_to_tokens(path_, keys = ["text"] ):
    out = []
    dict_out = {}  
    jin = json.load(open(path_, "r", encoding ="utf-8-sig"))
    for sent in jin:
        temps = [] 
        for word in sent:
            tword = []
            for key in keys: 
                try:
                    tword.append(word[key])
                except KeyError:
                    pass
            temps.append(tword) 
        out.append(temps)
        
    # populating the dict 
    for sent in out:
        for word in sent:
            d = {'upos' : word[1], 'lemma' : word[2]}
            if len(word) == 4:
                d['feats'] = word[3]
            else:
                d['feats'] = None
        dict_out[word[0]] = d  
    return out, dict_out

# %%
my_path = "proposal.txt"

processed_text = stanza_to_json(my_path)
res_list, res_dict = json_to_tokens("CSTA/processed_doc.json", keys = ["text", "upos", "lemma", "feats"])

# %% [markdown]
# # Ex 2
#
# From the Git profile of <a href="https://github.com/UniversalDependencies">UniversalDependencies</a> choose two repositories of your interest and download them with the command "git clone" after having positioned yourself in the folder of interest directly using the terminal.  Next, write a function that takes as argument the path to a Git folder. Using the "os" module, extract the path to all the ".conllu" files and process them to obtain for each file a dictionary whose keys will be tokens, and the ralated values will be a dictionary with the following information: lemma, and pos. Save all the dictionaries in a list and return it. Do this for both Git directories. At the end of the process make sure you get a list containing all the lists of the various dictionaries. Would you be able to attach the name of the repository you got the data from to each list?

# %%
import os
import re

directory_1 = "C:/Users/Daniel/CSTA_tutor/exercises/UD_Italian-PoSTWITA/"
directory_2 = "C:/Users/Daniel/CSTA_tutor/exercises/UD_Italian-TWITTIRO/"
directories = [directory_1, directory_2]

# %%
def get_conllu_features(path):
    files = [file for file in os.listdir(path) if ".conllu" in file]
    all_conllu_dataset = []
    for file in files:
        dataset = {}
        for line in open(f"{path}{file}", encoding="utf8"):
            if re.search("^[0-9]", line):
                features = line.split("\t")[1:4]
                dataset[features[0]] = {'lemma' : features[1], 'POS' : features[2]}
        all_conllu_dataset.append(dataset)
    return all_conllu_dataset

# %%
final_dataset = []
for dir_ in directories: 
    final_dataset.append(get_conllu_features(dir_))

# %% [markdown]
# Would you be able to attach the name of the repository you got the data from to each list?

# %%
dir_names = [name.split("/")[-2] for name in directories]
list(zip(dir_names, final_dataset))

# %% [markdown]
# # Ex 3
#
# On this <a href="https://www.tripadvisor.it/Tourism-g194889-Rovereto_Province_of_Trento_Trentino_Alto_Adige-Vacations.html">page</a> you will find a number of places in Rovereto which have been reviewed by users. Using selenium and BeautifoulSoup, scrape the url and for each item extract the reviews at the bottom of each page.In particular, for each review extract and save in a dictionary the following information: name of the reviewer, location (if any), number of reviews, rating, number of likes, date, title, and text of the review. The final dataset will consist of a dictionary that has the name of the location/activity as key and dictionaries with the information from the different reviews as values.  Divide up the code in an appropriate and functional way, making use of several functions.

# %% [markdown]
# ## SOLUTION
#
# The first thing do to in order to scrape properly the website is to study it and understand which are the common patterns in it. Scraping the links of all the items you can see that there are three types of review:
# - <p>https://www.tripadvisor.it/<b>Hotel_Review</b> ...</p>
# - <p>https://www.tripadvisor.it/<b>Attraction_Review</b> ...</p>
# - <p>https://www.tripadvisor.it/<b>Restaurant_Review</b> ...</p>
#
# If you take a look at the design of the website and therefore at the html codes of the three types of URLs, you will realise that they differ in certain details. In order to be able to scrape all links, I have created three functions that manage the scraping of the three different types of links.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

driver = webdriver.Chrome("C://Users/Daniel/CSTA_tutor/exercises/solutions/chromedriver.exe")
url = "https://www.tripadvisor.it/Tourism-g194889-Rovereto_Province_of_Trento_Trentino_Alto_Adige-Vacations.html"

# %%
def get_items(driver_, url_):
    time.sleep(2)
    driver.get(url_)
    soup = BeautifulSoup(driver.page_source)
    items = soup.find_all("li", class_="cNVSx Fg I")
    names = [i.find("div", class_="bsLRU btBEK fUpii").get_text() for i in items]
    base_url = "https://www.tripadvisor.it"
    links = [base_url + i.find("a")['href'] for i in items]
    # Extracting the letter in position "len(base_url) + 1" as website typology
    type_of_rev = [el[len(base_url) + 1] for el in links]
    return list(zip(names,links,type_of_rev))

# %%
def type_h(html):
    reviews_info = []
    reviews = html.find_all("div", class_="cWwQK MC R2 Gi z Z BB dXjiy")
    for rev in reviews:
        try: 
            rev_info = {}
            rev_info['name'] = rev.find("div", class_="bcaHz").find("a").get_text()
            
            # .split()[-2:] returns the last two elements of the list
            # " ".join(...) return a string made of all the el. of the list divided by " "
            rev_info['date'] = " ".join(rev.find("div", class_="bcaHz").find("span").get_text().split()[-2:])
            try:
                rev_info['location'] = rev.find("span", class_="default ShLyt small").get_text()
            except:
                rev_info['location'] = None
                
            # both num. of rev. and likes are stored in similar tags
            no_rev_likes = [i.get_text() for i in rev.find_all("span", class_="ckXjS")]
            rev_info['no_reviews'] = no_rev_likes[0]
            if len(no_rev_likes) > 1:
                rev_info['likes'] = no_rev_likes[1]
                
            # ratings are created using different classes in the same tag, i.e. <span class="ui_bubble_rating bubble_40">:
            # "ui_bubble_rating bubble_10", "ui_bubble_rating bubble_20", ... , "ui_bubble_rating bubble_50"
            # The number in the second el. of our class gives us the rating: bubble_10 --> 1/5, ... ,bubble_50 --> 5/5
            # I used the the first digit of the final number as rating 
            # .find("span")['class'] returns the two values of the "class" in a list: ['ui_bubble_rating', 'bubble_40']
            # .find("span")['class'][1] --> 'bubble_40'
            # .find("span")['class'][-2] --> 4
            rev_info['rating'] = rev.find("div", class_="emWez F1").find("span")['class'][1][-2]
            rev_info['title'] = rev.find("div", class_="fpMxB MC _S b S6 H5 _a").find("span").get_text()
            rev_info['text'] = rev.find("q", class_="XllAv H4 _a").get_text()
            reviews_info.append(rev_info)
        except AttributeError as e: 
            continue
    
    return reviews_info


def type_a(html): 
    reviews_info = []
    # recursive=False --> find_all returns just the div tags directly connected to <div class="bPhtn"> 
    reviews = html.find("div", class_="bPhtn").find_all("div", recursive=False)
    
    for rev in reviews:
        try: 
            rev_info = {}

            # scraping name,locations, no reviews, places in three <span>
            # tags inside the <div class="cjhIj"> one. 
            n_l_r = [i.get_text() for i in rev.find("div", class_="cjhIj").find_all("span")]

            # As the location coulb be absent the resulting list can be
            # of len 3 (location present) or 2 (location absent)
            if len(n_l_r) == 3:
                rev_info['name'] = n_l_r[0]
                rev_info['location'] = n_l_r[1]
                rev_info['no_reviews'] = n_l_r[2]
            else: 
                rev_info['name'] = n_l_r[0]
                rev_info['location'] = None
                rev_info['no_reviews'] = n_l_r[1]

            rev_info['rating'] = rev.find("svg", class_="RWYkj d H0")['title']
            rev_info['no_likes'] = rev.find("span", class_="WlYyy bTDWl").get_text()
            rev_info['date'] = rev.find("div", class_="WlYyy diXIH cspKb bQCoY").get_text()

            # title and text she the same tag, i.e. <span class="NejBf">
            title_text = [i.get_text() for i in rev.find_all("span", class_="NejBf")]
            rev_info['title'] = title_text[0]
            rev_info['text'] = title_text[1]

            #updating the list of all the reviwes
            reviews_info.append(rev_info)
        except AttributeError as e: 
            continue
            
    return reviews_info


def type_r(html):
    reviews_info = []
    reviews = html.find_all("div", class_="rev_wrap ui_columns is-multiline")
    for rev in reviews:
        try:
            rev_info = {}
            rev_info['name'] = rev.find("div", class_="info_text pointer_cursor").get_text()
            rev_info['no_reviews'] = rev.find("span", class_="badgeText").get_text()[0]
            rev_info['rating'] = rev.find("span", class_="ui_bubble_rating")['class'][1][-2]
            rev_info['date'] = rev.find("span", class_="ratingDate")['title']
            rev_info['title'] = rev.find("span", class_="noQuotes").get_text()
            rev_info['text'] = rev.find("p", class_="partial_entry").get_text()
            rev_info['likes'] = rev.find("span", class_="numHelp").get_text()
            reviews_info.append(rev_info)
        except AttributeError as e: 
            continue
    
    return reviews_info

# %%
def get_reviews_by_type(driver_, url_, type_):
    time.sleep(2)
    driver_.get(url_)
    soup = BeautifulSoup(driver.page_source)
    if type_ == "H":
        return type_h(soup)
    elif type_ == "A":
        return type_a(soup)
    elif type_ == "R":
        return type_r(soup)
    else:
        return "ERROR"

# %%
dataset = {}
items = set(get_items(driver,url))
for name,link,rev_type in items:
    print(name)
    dataset[name] = get_reviews_by_type(driver,link,rev_type)
# Out:
# Ristorante il Doge
# Palazzo de' Cobelli
# Chiesa di Santa Maria del Carmine
# B&B Diele
# Casa del Pittore
# Il Ristorante Novecento Dell'Hotel Rovereto
# La Caffetteria Bontadi
# Trattoria Bar Christian
# Ruina Dantesca
# La Pizia Pizza & Ristò
# Viadante 20
# Museo Civico di Rovereto
# Ristorante Al Lupo
# Nero Caffè
# Santa Maria delle Grazie
# Caverna Damiano Chiesa
# Azienda Agricola Balter
# Snack Bar Stella d'Italia
# Museo Storico Italiano della Guerra
# Assaporando Trattoria
# B&B Relais Mozart
# Cammino dei Dinosauri
# Castel Dante Sacrario AI Caduti
# Ristorante San Colombano
# Chiesa Arcipretale di San Marco
# Hotel Rovereto
# Bar Circolo SantaMaria
# B&B Casa dei Turchi
# Al Silenzio
# Piazza Rosmini
# Casa dei Turchi
# Colle Ameno Rooms & Breakfast
# Hotel Leon d'Oro
# Campana dei Caduti
# Moja
# River
# Bar Rosmini
# Osteria del Pettirosso
# Vanila Caffe
# Museo di Arte Moderna e Contemporanea di Trento e Rovereto
# L'orto di Pitagora
# Hotel Sant'Ilario
# Casa D'Arte Futurista Depero
# Bar Street Bikers
# Putipù
# Biblioteca Civica
# B&B Manu & Dige
# Hotel Flora
# Caffe Bontadi

# %%
dataset
# Out:
# {'Ristorante il Doge': [{'name': '286fathib',
#    'no_reviews': '9',
#    'rating': '1',
#    'date': '11 novembre 2021',
#    'title': 'Lontani dal mistieri.',
#    'text': 'Siamo in tre.\nPiatti senze sapore\nMal presentati.\nNn torniamo\nPiu. Ce di melio.\nÀ rovereto.\nE securamento.\nPiu professionale.',
#    'likes': ''},
#   {'name': '102marcog',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '11 novembre 2021',
#    'title': 'Un bel ristorantino dove si mangia bene e si pende il giuto',
#    'text': "Ho cento in questo ristorante su consiglio dell'albergo in cui soggiornavo e devo ammettere che è stato un ottimo consiglio. Ho provato un piatto unico tipico assaggiando prodotti diversi: canederli, tagliatelle al cervo, gulash con polenta e un ottimo tortino al cioccolato con cuore bianco....Tutto veramente ottimo. Viene offerta anche un'ottima selezione di vini anche se io ho scelto di non prenderne. Il personale è stato molto gentile. Il servizio rapido. Il locale è molto bello, piccolo e intimo. Ottima esperienza.Più",
#    'likes': ''},
#   {'name': 'Culture20543588464',
#    'no_reviews': '1',
#    'rating': '4',
#    'date': '8 novembre 2021',
#    'title': 'Pranzo a Rovereto',
#    'text': 'Giro a Rovereto                                                   Alla ora di pranzo ho provato questo ristorante di cui me ne avevano parlato. Ho mangiato bene con porzioni eccessive ma di livello sia come materi prime che per presentazione. Il prezzo in linea col locale.',
#    'likes': ''},
#   {'name': 'alessandrocM4995JO',
#    'no_reviews': '3',
#    'rating': '4',
#    'date': '7 novembre 2021',
#    'title': 'Visita Mart',
#    'text': 'Bella location tra i volti in pietra. Buon cibo della tradizione trentina. Ottima cantina. Personale preparato e cortese',
#    'likes': ''},
#   {'name': 'Cricri',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '5 novembre 2021',
#    'title': 'Bella location, buoni piatti',
#    'text': 'Personale gentile, bellissima location, piatti buoni e abbondanti, conto giusto, consigliato se vi trovate in centro a Rovereto!',
#    'likes': ''},
#   {'name': 'annalisa c',
#    'no_reviews': '2',
#    'rating': '2',
#    'date': '10 ottobre 2021',
#    'title': 'ASPETTATIVE DISILLUSE',
#    'text': "Abbiamo cenato in questo ristorante perché consigliato. Atmosfera piacevole e locale molto particolare. Ma... ci siamo seduti alle 2030 e il cameriere si è presentato al tavolo per ordinare da bere dopo 30 minuti, affettati arrivati dopo molto tempo e infine abbiamo ordinato un secondo...che è arrivato al tavolo dopo le 22! Servizio pessimo. I secondi non entusiasmanti. Una grande delusione. In cassa si sono scusati per l'attesa. ApprezzabilePiù",
#    'likes': ''},
#   {'name': 'Alex_Di_Valentino',
#    'no_reviews': '3',
#    'rating': '4',
#    'date': '5 settembre 2021',
#    'title': 'Ottime tagliatelle',
#    'text': 'Ottime tagliatelle fatte in casa condite con il cervo, eccellente la scelta dei vini tutti locali ma anche qualcosa di fuori… Servizio impeccabile locale pulito prezzi onesti',
#    'likes': ''},
#   {'name': 'MedusaMilano',
#    'no_reviews': '6',
#    'rating': '4',
#    'date': '25 agosto 2021',
#    'title': 'MAGGIORE ATTENZIONE',
#    'text': "Locale d'atmosfera, camerieri gentili e piatti gustosi, peccato che abbia chiesto una pasta con pomodorini secchi e capperi ma senza burrata specificando di essere VEGANA e, mentre la mangiavo, mi sono accorta che era stata mantecata con il parmigiano ! \nSe un cliente fa espressa...richiesta si dovrebbe fare maggiore attenzione. Prezzo nella media.Più",
#    'likes': '1 \xa0'},
#   {'name': 'Danilo P',
#    'no_reviews': '6',
#    'rating': '4',
#    'date': '24 agosto 2021',
#    'title': 'Sulla via di Casa Depero',
#    'text': "Ristorante centrale , bella location,ricavato da una cantina del '600, che offre piatti molto buoni e ben impiattati. Ordinati piatto unico tipico trentino con canederli pappardelle carne di cervo e polenta, perfetto ; e il tris di dolci cioe' gelato con mirtilli caldi , strudel,...tortino al cioccolato: il meglio del trentino. vicinissimo a Casa Depero. ConsigliatissimoPiù",
#    'likes': ''},
#   {'name': 'Sandro83C',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '19 agosto 2021',
#    'title': 'Pranzo eccellente, servizio perfetto',
#    'text': 'Location suggestiva nel centro storico, ampio menù di specialità locali trentine, ok anche la carta dei vini.\nCucina di ottimo livello, eccellente fattura dei piatti, buon rapporto qualità/prezzo.\nNota di merito al servizio, pressoché perfetto: personale attento, efficiente, rapido e competente.',
#    'likes': ''}],
#  "Palazzo de' Cobelli": [{'name': 'Alessandro F',
#    'location': 'Milano, Italia',
#    'no_reviews': '25.368 contributi',
#    'rating': 'Punteggio 4,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 24 agosto 2018',
#    'title': 'Ex filanda',
#    'text': 'Palazzo cinquecentesco ereditato dai De Cobelli dopo il matrimonio tra Barbara de Cobelli e Camillo Cosimi alla fine del diciottesimo secolo'},
#   {'name': 'Gedii',
#    'location': 'Roma, Italia',
#    'no_reviews': '13.047 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 24 settembre 2016',
#    'title': 'Palazzo dalla storia interessante...',
#    'text': 'Il palazzo, costruito dalla nobile famiglia roveretana dei Cosimi, verso la fine del \'500 si trova al 55 di Via Santa Maria una delle vie del centro storico della città. Palazzo de\' Cobelli fu "uno tra i pochi palazzi che potevano dare ospitalità ed immunità\'\' a chi, commesso un delitto, riusciva a potervi entrare. La facciata, in stile settecentesco dalle forti influenze barocche, è una tra le più belle dell\'epoca dal punto di vista architettonico; particolare la loggetta presenta nel piano nobile (primo piano) posta in corrispondenza del portale d\'ingresso; sul retro si trovano ampie scuderie e magazzini.'},
#   {'name': 'dreamyviajero',
#    'location': 'Italia',
#    'no_reviews': '5.731 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 1 aprile 2016',
#    'title': "Palazzo de' Cobelli",
#    'text': "Il Palazzo de' Cobelli ha una facciata molto bella. La nostra visita si è limitata ai soli esterni. Si consiglia, una volta visitato il Museo Storico della Grande Guerra, di allungare di poco la passeggiata per vedere questo bel palazzo."}],
#  'Chiesa di Santa Maria del Carmine': [{'name': 'Alessandro S',
#    'location': 'Trento, Italia',
#    'no_reviews': '116 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 29 aprile 2018',
#    'title': 'Una chiesa Da vedere',
#    'text': "Non è un'attrazione turistica e nemmeno un museo ma la chiesa di santa maria del carmine è sicuramente una delle chiese più belle della regione. Merita di essere vista e se volete anche partecipare ad una funzione per apprezzare l'acustica dei canti."},
#   {'name': 'Anna L',
#    'location': 'Bologna, Italia',
#    'no_reviews': '21 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '1',
#    'date': 'Scritta in data 13 febbraio 2018',
#    'title': 'Meravigliosa',
#    'text': "L'aria che si respira dentro in questa chiesa e' di grande pace.Un apprezzamento al parroco don Francesco per la grande persona!!"},
#   {'name': 'Gianmario',
#    'location': 'Milano, Italia',
#    'no_reviews': '10 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 14 gennaio 2018',
#    'title': 'Viste certe cattedrali ...',
#    'text': "Ogni chiesa si assomiglia, per opulenza di marmo, di fatica e sacrificio costato alla povera gente che nei secoli ha contribuito con l'8x1000 a costruirla. Un luogo di culto per chi ci creda o no."},
#   {'name': 'Roberta V',
#    'location': 'Rho, Italia',
#    'no_reviews': '3.677 contributi',
#    'rating': 'Punteggio 4,0 su 5',
#    'no_likes': '1',
#    'date': 'Scritta in data 10 maggio 2017',
#    'title': 'Chiesa di S. Maria del Carmine',
#    'text': "Una delle chiese più antiche della città, il cui primo nucleo risale al 1290 su commissione di Guglielmo di Castelbarco, fu compiuta nel 1770. A fianco della chiesa venne costruito, su disposizione testamentaria di Guglielmo Castelbarco, un convento, dapprima destinato ai Frati Minori e, successivamente, ai Carmelitani che vi rimasero fino al 1785, quando l'Austria soppresse l'Ordine. Da qui la denominazione di S. Maria del Monte Carmelo."},
#   {'name': 'Gedii',
#    'location': 'Roma, Italia',
#    'no_reviews': '13.047 contributi',
#    'rating': 'Punteggio 4,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 24 settembre 2016',
#    'title': 'Una delle Chiese più antiche di Rovereto...',
#    'text': "E' una delle Chiese più antiche della città, il suo primo nucleo risale al 1290, su commissione di Guglielmo di Castelbarco, ma venne compiuta solo nel 1770. Di fianco della Chiesa venne costruito (su disposizione testamentaria di Guglielmo Castelbarco) un Convento, dapprima destinato ai Frati Minori, successivamente passò ai Carmelitani (da qui la denominazione di S. Maria del Monte Carmelo) che vi rimasero fino al 1785, quando l'Austria soppresse l'Ordine. Interno a croce latina, con due Cappelle per lato, più altre quattro nel transetto, tutti ornati da bellissimi Altari in marmi policromi con pale settecentesche; mentre nel presbiterio, oltre ad un monumentale Altare ornato di statue di angeli e Santi, vi sono opere pittoriche di Gasparantonio Baroni del 1019 Cavalcabò."},
#   {'name': 'Alessandro F',
#    'location': 'Milano, Italia',
#    'no_reviews': '25.368 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '98',
#    'date': '',
#    'title': 'Bellissime decorazioni interne',
#    'text': 'Esternamente è una chiesa classica comune del XVIII secolo, entrando invece si rimane piacevolmente colpiti dalle decorazioni della volta e della cupola.La navata solitaria intatta è mirabilmente decorata in stile quasi arabesco con innumerevoli foglie di quercia.Solo la vista di questi soffitti è sufficiente per visitare questa chiesa.'}],
#  'B&B Diele': [{'name': 'Tiziano P',
#    'date': 'set 2021',
#    'location': None,
#    'no_reviews': '1',
#    'likes': '1',
#    'rating': '5',
#    'title': 'ACCOGLIENZA FANTASTICA',
#    'text': "Siccome dovevo fare un intervento chirurgico ho pernottato una notte con mia moglie, dopodiché ha pernottato mia moglie fino alla mia dimissione.  Molto comodo perché situato a 5 minuti dall'ospedale, questo b&b ci ha sorpreso per la disponibilità e la cortesia della signora Paola.  In poche parole ci ha dato l impressione di essere in famiglia. Camera spaziosa con bagno , bottigliette d'acqua a disposizione. Colazione da favola con torte,crostate e biscotti fatti in casa.  Un grazie di cuore alla signora Paola e a tutti i suoi collaboratori. Complimenti. Un saluto e un abbraccio.               Tiziano e Roberta"},
#   {'name': 'Rama146',
#    'date': 'ago 2021',
#    'location': 'Livorno, Italia',
#    'no_reviews': '75',
#    'likes': '58',
#    'rating': '3',
#    'title': 'Due notti a Rovereto',
#    'text': 'Sono stato un paio di notti a Rovereto e ho soggiornato presso questo B&B. La struttura è pulita, il bagno è in camera ed è molto fornito, nella nostra stanza “Irene” forse la doccia è troppo piccola ed una persona anziana e/o corpulenta potrebbe starci scomoda. La colazione ci è piaciuta e i dolci, fatti dalla proprietaria, molto gradevoli, viene preparata con grande attenzione e cura dalla proprietaria,acqua fredda in bottiglietta sempre a disposizione degli ospiti.  Purtroppo non posso dare di più perché la camera era molto calda, la prima notte non sono riuscito praticamente a dormire: non c’è aria condizionata e la persiana scorrevole non fa passare aria e non è possibile dormire con tutto spalancato essendoci comunque delle case di fronte. C’è un ventilatore di quelli economici poco efficace e rumoroso, a noi non è servito a niente. Il letto e i cuscini li ho trovati scomodi, l’arredamento sarebbe da rimodernare… Non c’è la tv in camera e credo che agli ospiti potrebbe servire. L’esperienza è stata sufficiente e consiglio comunque la struttura a chi passa per Rovereto. Prezzo 170 euro per due notti tassa di soggiorno compresa  PS: consiglio per tutti: non prenotate i musei in anticipo ma arrivate in struttura e fate la Trentino Guest card.…'},
#   {'name': 'Giuseppe M',
#    'date': 'lug 2021',
#    'location': None,
#    'no_reviews': '1',
#    'rating': '5',
#    'title': 'Soggiorno fantastico',
#    'text': 'Siamo arrivati in cinque con le nostre bici ed abbiamo trovato qualcosa di inaspettato. Abbiamo soggiornato negli anni in molti B&B nelle nostre "scorribande" ma mai avevamo trovato una simile accoglienza, gentilezza e disponibilità da parte del gestore.  La signora Paola ci ha fatto sentire come in famiglia e ci ha deliziato con una colazione particolarmente ricca, ottima per poi riprendere il nostro percorso in bici. Insomma, consigliato a tutti quelli che vogliono mettersi in viaggio e fare una sosta a Rovereto che è anche una bella cittadina da visitare.'},
#   {'name': 'Carla Pastori',
#    'date': 'nov 2020',
#    'location': None,
#    'no_reviews': '1',
#    'rating': '5',
#    'title': 'Struttura ottima',
#    'text': "Nei nostri vari soggiorni a Rovereto abbiamo alloggiato al B&B Diele e ci siamo trovati benissimo, tanto noi quanto la nostra cagnolina. Zona tranquilla e servita, camere spaziose, confortevoli e pulite, bagno fornito di tutto l'immaginabile, colazione ottima. La proprietaria, sig.ra Paola, ci ha fatto sentire come a casa nostra grazie alla sua cordialità e disponibilità."},
#   {'name': 'Silvia',
#    'date': 'ott 2020',
#    'location': None,
#    'no_reviews': '3',
#    'rating': '5',
#    'title': 'Cortesia e disponibilità',
#    'text': "Abbiamo scelto questo B&B per necessità di soggiornare vicino all'ospedale (5 min a piedi). Il B&B è situato in una strada tranquilla e silenziosa.  Camere ampie, luminose, pulitissime e con balcone. Ci siamo trovati davvero molto bene, grazie sopratutto alla cordialità e alla gentilezza di Paola che è venuta incontro alle nostre esigenze con grande disponibilità. Colazione ottima con torte buonissime fatte in casa ed una particolare e piacevole attenzione per me che sono intollerante al glutine. Grazie di tutto!"}],
#  'Casa del Pittore': [{'name': 'Chiara M',
#    'date': 'ago 2021',
#    'location': 'Milano, Italia',
#    'no_reviews': '26',
#    'likes': '20',
#    'rating': '5',
#    'title': 'Bike-friendly',
#    'text': 'Ideale per noi ciclo viaggiatori, sia per la posizione che permette di raggiungere le numerose ciclabili lungo l’Adige o in alternativa gli off road in montagna, sia per l’organizzazione della struttura, che è fornita di appositi spazi ed attrezzature dedicati alle bici. Per finire poi la giornata - dopo tanti chilometri - con una sauna o un idromassaggio!'},
#   {'name': 'Fulvia B',
#    'date': 'giu 2021',
#    'location': None,
#    'no_reviews': '2',
#    'rating': '5',
#    'title': 'Pulizia eccellente',
#    'text': "Camere belle e spaziose con cucina attrezzata di tutto. Bagno con doccia grande e dotato di phon per i capelli Pulizi ecacellente.  Grande disponibilità da parte dei proprietari. Possibilità  di far colazione all'aperto  fuori data camera."},
#   {'name': 'Florine Offergelt',
#    'date': 'giu 2021',
#    'location': None,
#    'no_reviews': '2',
#    'rating': '5',
#    'title': 'Recensione 5 stelle    ***** !!!',
#    'text': 'Ciao, buongiorno !  Alla Casa del Pittore non ci siamo trovati bene ma BENISSIMO! Stanze ristrutturate con gusto ed eleganza e non manca nulla! (letti comodi e bagno/doccia super!)  Proprietari gentili e cortesi. Ritorniamo MOLTOOOO volentieri!  Florine Offergelt e Gianmauro Anchisi. 🌷'},
#   {'name': 'FranciRebby',
#    'date': 'ago 2020',
#    'location': 'Termini Imerese, Italia',
#    'no_reviews': '79',
#    'likes': '59',
#    'rating': '5',
#    'title': 'Ottimo albergo di campagna addossato alla città, cinque minuti a piedi.',
#    'text': 'Albergo di campagna con vista sui monti, fresco, con prato ed altri servizi non da noi utilizzati. Gentilissima la famiglia che lo gestisce, fornisce la card "gratuita" per visitare tutti i musei del Trentino. Non abbiamo usufruito della colazione. Stanza pulitissima e silenziosa.'},
#   {'name': 'marisab',
#    'date': 'set 2019',
#    'location': None,
#    'no_reviews': '2',
#    'rating': '5',
#    'title': 'Eccellente',
#    'text': 'Incantevole,molto curato anche nei dettagli...la camera molto spaziosa arredata con gusto e tutto molto pulito..colazione abbondante e vicinanza al centro città..da consigliare sicuramente per un piacevole soggiorno'}],
#  "Il Ristorante Novecento Dell'Hotel Rovereto": [{'name': 'NicoleBertucci',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '15 agosto 2021',
#    'title': 'Buon ristorante',
#    'text': 'Bellissimo ristorante che presenta un menù ricercato con ingredienti di ottima qualità. Consiglio di provare la pizza, veramente buona. Personale gentile e buon rapporto qualità prezzo.',
#    'likes': ''},
#   {'name': '433pierluigit',
#    'no_reviews': '9',
#    'rating': '5',
#    'date': '2 agosto 2021',
#    'title': 'Qualità degli ingredienti, maestria e servizio impeccabile. ',
#    'text': "Il connubio perfetto tra forma e sostanza, un menu che accontenta dal palato più raffinato al patito per la pizza, il tutto in un atmosfera armoniosa, e con un piacevole e originale tocco  d'arte.",
#    'likes': ''},
#   {'name': 'roberto g',
#    'no_reviews': '6',
#    'rating': '5',
#    'date': '8 luglio 2021',
#    'title': 'Mostre Mart ',
#    'text': "Ambiente elegante ed accogliente. I cibi sono di ottima  qualità e fattura. Ineguagliabile il riso Venere con gamberetti, verdure e curry, così come l'insalata di polpo e un gustosissimo strudel e gelato di vaniglia per finire. Le quantità dei piatti non si fanno desiderare, ed...abbiamo rimandato ad una prossima volta la degustazione dei secondi piatti. La cantina dei vini è molto fornita. Buono il rapporto prezzo/qualità. Sicuramente un'esperienza da ripetere in occasione di una prossima visita al Mart di Rovereto.Più",
#    'likes': ''},
#   {'name': 'Danyb45',
#    'no_reviews': '6',
#    'rating': '4',
#    'date': '26 agosto 2020',
#    'title': 'Non fatevi trarre in inganno...',
#    'text': 'Tranquilli, non è il solito ristorante di un hotel, ma un ristorante con piatti appetitosi e ben presentati e prezzi che rispettano il rapporto qualità/prezzo. Consiglio i tagliolini di farro con ragù di pesce persico e non fatevi sfuggire uno strudel straordinario.',
#    'likes': '3 \xa0'},
#   {'name': 'casazormar',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '6 marzo 2020',
#    'title': 'Esperienza e professionalità',
#    'text': 'Ho mangiato in diverse occasioni in questo ristorante ed è sempre impeccabile. Oltre al cibo, il servizio è professionale e la sala è elegante nella sua semplicità. Pulitissimo. È evidente la passione dei titolari che sono del mestiere. Complimenti.',
#    'likes': ''},
#   {'name': 'andreacR4070HF',
#    'no_reviews': '4',
#    'rating': '4',
#    'date': '8 febbraio 2020',
#    'title': 'Cena',
#    'text': 'Ci siamo stati a cena, ottima location, ottimi prodotti, e personale cordiale e preparato. Ci ritorneremo sicuramente. Lo consigliamo vivamente.',
#    'likes': '2 \xa0'},
#   {'name': 'Lucac70',
#    'no_reviews': '2',
#    'rating': '3',
#    'date': '6 gennaio 2020',
#    'title': 'Sempre Nella Media',
#    'text': 'Mi trovo a confermare il giudizio dato in Passato: i prezzi sono veramente alti per la cena assaporata. Non abbiamo trovato quel guizzo che ti fa dare un giudizio migliore. Piatti buoni e servizio elegante.',
#    'likes': '3 \xa0'},
#   {'name': 'andrea m',
#    'no_reviews': '6',
#    'rating': '3',
#    'date': '15 dicembre 2019',
#    'title': 'Bella esperienza',
#    'text': 'Ho alloggiato a dicembre con la mia famiglia,mia moglie, mia figlia il marito e la nipotina di 3 anni.La sera abbiamo cenato presso il ristorante dell"hotel devo dire che a prima vista appare un locale freddo poco illuminato per essere un locale di semi montagna....Menu molto limitato nell\'offerta e pochissimi i piatti tipici che si dovrebbero trovare in Trentino\nIn compenso abbiamo apprezzato molto il gran bollito di carne servito al carrello .Carne ottima e grande assortimento.Personale gentile e professionale buon rapporto tra qualita  e prezzoPiù',
#    'likes': '1 \xa0'},
#   {'name': 'PalombiG',
#    'no_reviews': '3',
#    'rating': '4',
#    'date': '3 dicembre 2019',
#    'title': 'Davvero molto buono',
#    'text': 'Piatti mantovanini come i deliziosi tortelli con la zucca e il carrello dei bolliti e piatti trentini come il filetto di lavarello con cavolo nero e glassa di arancia. Ingredienti eccellenti e della zona.\nInpiattamento da grande ristorante.\nSapori impeccabili.\nDavvero un ottimo ristorante.',
#    'likes': ''},
#   {'name': 'W9355UFalessandrab',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '16 novembre 2019',
#    'title': 'LA MADELINE. ',
#    'text': 'Tra le righe del racconto di Proust, aperta la porta del ristorante, quel profumo pieno di ricordi. Mi sono ritrovata a casa, la sera dei grandi bolliti e delle patate cotte nel brodo. La dolcezza di mia madre e il piacere di stare insieme. Mi...sono seduta e mi sono lasciata cullare da questo ricordo. Ogni volta che torno a Rovereto non rinuncio ad un momento speciale, una cena nel mio ristorante preferito.Più',
#    'likes': ''}],
#  'La Caffetteria Bontadi': [{'name': 'Massimiliano F',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '2 novembre 2021',
#    'title': 'Wow!',
#    'text': 'Ben più di un bar o di una pasticceria. Un sorprendente luogo dove scoprire sapori genuini e panini fatti in casa con grande qualità di ingredienti. Davvero niente male!',
#    'likes': ''},
#   {'name': 'giuliii107',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '5 settembre 2021',
#    'title': 'Eccellente',
#    'text': "Locale carino situato nel centro di Rovereto con a disposizione tavolini sulla piazza. Per la colazione c'è un'ottima offerta di brioche e torte varie (io ho preso una Linzer squisita che mi è arrivata pure calda!).",
#    'likes': ''},
#   {'name': 'S4454ACvalterb',
#    'no_reviews': '1',
#    'rating': '1',
#    'date': '21 agosto 2021',
#    'title': 'Locale',
#    'text': "Sono entrato ed ho ordinato un caffè e una brioche Ho chiesto anche un bicchiere d'acqua del rubinetto la cameriera acida mi ha risposto che loro vendono le bottigliette e che non servono acqua del rubinetto non mi è mai capitato in nessun bar di...ricevere questa risposta attenzione mi fanno pagare praticamente anche l'aria che respiratePiù",
#    'likes': ''},
#   {'name': '_S0le_85_',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '14 agosto 2021',
#    'title': 'Ottima pausa pranzo ',
#    'text': "Scelto casualmente per una pausa pranzo veloce prima di recarsi al mart, non potevo chiedere di più....\nAppena letto il listino si può essere colpiti dai prezzi un po' altini dei panini/toast, ma la qualità vale il prezzo.... sia come dimensione sia come farcitura... ottima...anche la tortina all'albicocca, consigliata dalla cameriera\nServizio veloce e molto cortese.\nBella location in una piazzetta tranquilla e pittoresca.Più",
#    'likes': ''},
#   {'name': 'Gargio76',
#    'no_reviews': '9',
#    'rating': '4',
#    'date': '3 ottobre 2020',
#    'title': 'Buona!',
#    'text': "Situato in una deliziosa piazzetta questo è un caffé storico di Rovereto. Durante la bella stagione è possibile, anche, mangiare e sostare ad uno dei tanti tavolini all'aperto.\nServizio molto cortese e l'idea di dare ai panini nomi di famosi musei del mondo è davvero...simpatica!\nPanini molto buoni e ben farciti al giusto prezzo! Decisamente consigliato per una sosta ristoratrice passeggiando per il centro storico di questa bella cittadina. @gargio76Più",
#    'likes': '3 \xa0'},
#   {'name': 'Franchini1956',
#    'no_reviews': '8',
#    'rating': '4',
#    'date': '9 settembre 2020',
#    'title': 'Buono',
#    'text': 'Buono, una delle cose da fare a Rovereto. Il caffè è buonissimo ma hanno un grande assortimento di panini e di piatti.',
#    'likes': '30 \xa0'},
#   {'name': 'davidebianchi666',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '3 settembre 2020',
#    'title': 'Pausa caffe',
#    'text': 'Di ritorno da gita in montagna decidiamo di fermarci per un tea e un caffe.\nottimo  \nPasticcini super\nTutto perfetto! consigliato',
#    'likes': '2 \xa0'},
#   {'name': 'biondabuongustaia',
#    'no_reviews': '6',
#    'rating': '5',
#    'date': '31 agosto 2020',
#    'title': 'Una dolce pausa!',
#    'text': 'Ci siamo fermati in questa caffetteria per una pausa caffè e dolcetto. \nCaffè di ottima qualità e dolci altrettanto gustosi, la mini Sacher era squisita.\nIl caffè intenso e deciso: mi è piaciuto molto, difatti ho comprato anche la bustina per farlo a casa di...loro produzione.\n\nPersonale gentilissimo.\nLo consiglio!Più',
#    'likes': '2 \xa0'},
#   {'name': 'AnneG291074',
#    'no_reviews': '1',
#    'rating': '4',
#    'date': '18 agosto 2020',
#    'title': 'Ottima qualità ',
#    'text': "Ci siamo fermati qui per pranzo. Panini un poco costosi (7/8 euro) ma l'ottima qualità  dei prodotti utilizzati giustifica il prezzo. Dolci per accompagnare il caffè ottimi.",
#    'likes': '2 \xa0'},
#   {'name': 'stefanor371',
#    'no_reviews': '1',
#    'rating': '2',
#    'date': '17 agosto 2020',
#    'title': 'Molto fumo...',
#    'text': 'Pranzo veloce con panini pretenziosi, con buoni ingredienti ma molto cari (8 euro) e con alcuni ingredienti mancanti (senape). Calice di traminer vergognoso, meno di mezza porzione. Avendolo fatto notare mi è stato risposto "mi dispiace"... eh si sa alla sorte avversa che riempie le...coppe nulla si può...\nStrudel decisamente, ma decisamente sotto la media della zona, servito senza neppure un tovagliolo, fortuna che davanti al locale c\'è una bella fontana pubblica... a ripensarci meriterebbero una stella, ma il caffè era buono...Più',
#    'likes': '2 \xa0'}],
#  'Trattoria Bar Christian': [{'name': 'Al_e_Fa53',
#    'no_reviews': '2',
#    'rating': '5',
#    'date': '4 novembre 2021',
#    'title': 'Bravi!',
#    'text': 'Molto bravi tutti i ragazzi! Intanto sono stati fra i pochi che ci hanno chiesto il Green Pass..., abbiamo mangiato con delle porzioni abbondantissime e di grande soddisfazione con prezzo "da studenti" ! Continuate così...',
#    'likes': ''},
#   {'name': 'angelotH8792WI',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '23 settembre 2021',
#    'title': 'Ottimo',
#    'text': 'Un ristorante eccezionale ,camerieri gentilissimi e il cibo super buono, e molto curato e molto abbondante, ci ritornerò sicuramente',
#    'likes': ''},
#   {'name': '932luigid',
#    'no_reviews': '4',
#    'rating': '5',
#    'date': '10 settembre 2021',
#    'title': 'Super',
#    'text': 'Un ristorante eccezionale a dir poco, camerieri gentilissimi e il cibo super buono, e molto curato e molto abbondante, ci ritornerò sicuramente se passo per Rovereto',
#    'likes': ''},
#   {'name': 'sabrinaz2018',
#    'no_reviews': '4',
#    'rating': '1',
#    'date': '9 settembre 2021',
#    'title': 'Educazione!!!!!',
#    'text': 'Cibo sempre buono ma non accettabile il servizio...\nUn piatto è arrivato 30 minuti dopo quando tutti avevamo finito e la cameriera nuova, per altro poco educata ,ha sostenuto che era stato ordinato tardi.\nNon è vero che il cliente ha sempre ragione,ma è certo...che l educazione è  dovuta. \nAlmeno un " cenno di scusa" era il minimo. \nClienti da tempo...\nDelusaPiù',
#    'likes': ''},
#   {'name': 'Navigate16106612592',
#    'no_reviews': '2',
#    'rating': '5',
#    'date': '9 settembre 2021',
#    'title': 'Qualità e quantità',
#    'text': 'Durante una mia breve permanenza presso Rovereto a causa di un tirocinio legale, ho deciso di affidarmi alle ottime recensioni di questa trattoria per il pranzo e per la cena; nonostante i grandi afflussi di clientela ad ogni  ora (segno anche questo di ottima fama...del luogo) e l’impossibilità di prenotazione; devo ammettere che quei 10-15 minuti di attesi sono pienamente restituisti con la grande qualità del cibo e i prezzi modici. Il cortile esterno è davvero molto grazioso e il giovane personale è cortese ed efficiente. La ragazza di nome Lucia, in particolare, è davvero molto gentile. P.S.: ottima birra ma non hanno il gin tonic ;)Più',
#    'likes': ''},
#   {'name': 'Attilia G',
#    'no_reviews': '4',
#    'rating': '5',
#    'date': '3 settembre 2021',
#    'title': 'Visita al Mart Rovereto.... ma pranzo migliore!!',
#    'text': 'Abbiamo pranzato per caso oggi in questa trattoria.Davvero cibo ottimo, quantità eccellente così come la gentilezza dei personale. Prezzo giustissimo.\nTorneremo a Rovereto solo per mangiare in questa trattoria!!!',
#    'likes': ''},
#   {'name': 'LucianaVitr',
#    'no_reviews': '4',
#    'rating': '5',
#    'date': '28 agosto 2021',
#    'title': 'Fama meritata!',
#    'text': 'Ottima cucina, porzioni generose, prezzi buoni e personale gentile! Una piccola attesa per prendere posto, ma ne è valsa la pena!',
#    'likes': ''},
#   {'name': 'danirenzo',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '27 agosto 2021',
#    'title': 'Che porzioni!!!',
#    'text': 'Porzioni enormi, ottima la pasta al pesto con vongole e mazzancolle, panini giganti, prezzi bassi. Ottimo rapporto qualità prezzo. Locale carino e personale gentile. Un pochino lunga l attesa . Stra consigliato',
#    'likes': ''},
#   {'name': 'gordian751',
#    'no_reviews': '1',
#    'rating': '4',
#    'date': '24 agosto 2021',
#    'title': 'Da non perdere',
#    'text': 'Trattoria in pieno centro di Rovereto gestito da tutti ragazzi. Bella la location dentro un cortile con tavoli all’aperto. \nQuando siamo andato noi (eravamo 7) non era possibile prenotare e bisognava mettersi in fila ed aspettare (1 ora circa) ma ne vale la pena!\nServizio...molto cordiale e disponibile. \nCibo veramente buono dai primi ai secondi ai dolci(consiglio il tiramisù). \nOttimo il rapporto qualità/prezzo. \nDa andare sicuramente se state a Rovereto anche di passaggio.Più',
#    'likes': ''},
#   {'name': 'giuliii107',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '22 agosto 2021',
#    'title': 'Imperdibile',
#    'text': "Locale un po' nascosto, ma all'interno ben curato e arredato.\nPiatti abbondanti, anche tipici della cucina trentina.\nConsigliatissimo!",
#    'likes': ''}],
#  'Ruina Dantesca': [{'name': 'GIUSEPPE C',
#    'location': 'Trento, Italia',
#    'no_reviews': '926 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '3',
#    'date': 'Scritta in data 5 dicembre 2018',
#    'title': 'Quella frana gigantesca',
#    'text': "Chi percorre la statale dell'Abetone e del Brennero, in direzione Nord, oltrepassato l'abitato di Ala e poco prima di Rovereto troverà una scritta a lato della strada che recita:  (Dante, XII canto dell'Inferno). Guardando verso destra noterete enormi massi rotolati dalla montagna. Un terremoto, una frana gigantesca, un cataclisma, la cui notizia si diffuse ben presto in tutta la Penisola. Nella stessa area (i Lavini di Marco) tra i massi rotolati a valle sono state rinvenute impronte di dinosauro. Un sentiero sta valorizzando la zona di questa straordinaria scoperta."},
#   {'name': 'Elena B',
#    'location': 'Cerea, Italia',
#    'no_reviews': '274 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 1 settembre 2018',
#    'title': 'Emozionante',
#    'text': 'La vista è stupenda, il significato che ha lo è ancora di più. Merita la visita, un pezzo di storia che in sè non è tanto, ma ha un grande valore.'},
#   {'name': 'Mario O',
#    'location': 'Villafranca di Verona, Italia',
#    'no_reviews': '898 contributi',
#    'rating': 'Punteggio 4,0 su 5',
#    'no_likes': '2',
#    'date': 'Scritta in data 8 agosto 2018',
#    'title': 'impressionante',
#    'text': 'Ogni volta che passo da qui non posso far a meno di guardare questa enorme frana raccontata anche da Dante nella Divina Commedia. Enormi massi di calcare grigio rotolati dalla montagna. Spettacolare.'},
#   {'name': 'Alessandro F',
#    'location': 'Milano, Italia',
#    'no_reviews': '25.368 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '1',
#    'date': 'Scritta in data 4 giugno 2018',
#    'title': '200 milioni di anni',
#    'text': 'Questi sono gli anni dei fossili di dinosauro trovati tra questi massi rotolati dalla montagna in una immensa frana citata anche da Dante Alighieri di passaggio su questa strada'},
#   {'name': 'mariarita p',
#    'location': 'Milano, Italia',
#    'no_reviews': '25.837 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '3',
#    'date': 'Scritta in data 11 dicembre 2017',
#    'title': 'Piacevole scoperta',
#    'text': 'Andando verso Rovereto dalla Statle ci siamo imbattuti nel cartello "Ruina dantesca", co relativa indicazione del Canto dell\'Inferno in cui è citata tale località. Non ho potuto fare a men odi andare a rileggermi questo "passo"'},
#   {'name': 'LellaCaponago',
#    'location': 'Caponago, Italia',
#    'no_reviews': '243 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '1',
#    'date': 'Scritta in data 25 novembre 2017',
#    'title': 'Scoperta per caso',
#    'text': 'Usciti dall’autostrada per coda, di ritorno dalla Val Gardena, scopriamo questo posto di cui non sapevamo l’esistenza ed in più nella località (Marco) che porta il nome di mio figlio!È citata in un canto “secondario” della Divina Commedia.Non tutti i mali (coda) vengono per nuocere.Ovviamente già in macchina ho cercato il passo dove viene citata.'},
#   {'name': 'sambenini',
#    'location': 'Riva Del Garda, Italia',
#    'no_reviews': '1.628 contributi',
#    'rating': 'Punteggio 4,0 su 5',
#    'no_likes': '4',
#    'date': 'Scritta in data 24 gennaio 2017',
#    'title': 'Una sorprendente scoperta!',
#    'text': 'Scoperta per via del tutto fortuita, passando in macchina sulla statale che da Marco "mena su per colle" è ineludibile non rimanere colpito o quantomeno influenzati da questo paesaggio Dantesco,  reso cupo e sinistro dagli enormi massi citati nel XII Canto dell\'Inferno. Magico e storico al tempo stesso, andateci.'},
#   {'name': 'MarcoBottura',
#    'location': 'Soliera, Italia',
#    'no_reviews': '116 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '3',
#    'date': 'Scritta in data 18 dicembre 2016',
#    'title': "L'entrata dell'inferno",
#    'text': 'Se in gioventù siete stati un po\' nerd; se ancor oggi leggete la rubrica "Non tutti sanno che..." de "La Settimana Enigmistica"; se amate verseggiare quelle due o tre terzine della Divina Commedia che ancora vi rimbalzano in testa; ma soprattutto se trascinate l\'intera famiglia a vedere i "gioielli" dell\'Italia, mentre moglie e figli strabuzzano gli occhi di nascosto; ebbene, siete i candidati ideali per  visitare la famosa "Ruìna Dantesca".Per questa destinazione è però necessario organizzare una sorta di imboscata: deviate dall\'Autostrada A 22 alla Strada Statale 12 adducendo problemi di traffico segnalati dal navigatore; quando vedrete, nei pressi di "Marco" (è una frazione di Rovereto, si chiama proprio così!), qualche ettaro di insignificanti massi rocciosi senza vegetazione, fermatevi sulla piazzola seguente; solo a questo punto esclamate: "Oibò, la Ruìna Dantesca! C\'è anche il cartello! Facciamo un giretto!". Mi raccomando: non state lì a spiegare la citazione dantesca (tanto è un casino). Dite piuttosto che si tratta dell\'entrata dell\'inferno (almeno i figli vi capiranno).'},
#   {'name': 'GIANLUCA G',
#    'location': 'Beinette, Italia',
#    'no_reviews': '111 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '1',
#    'date': 'Scritta in data 26 agosto 2016',
#    'title': 'Divina Commedia',
#    'text': "Percorrendo la strada tra Rovereto e Marco ( frazione di Rovereto ) ci si imbatte, sulla strada, nella ruina dantesca che sembrerebbe essere nominata nella Divina Commedia, per essere apprezzata occorre fermare l'auto e dedicare qualche minuto."},
#   {'name': '🇮🇹 Germano 🇮🇹',
#    'location': 'Rovereto, Italia',
#    'no_reviews': '1.445 contributi',
#    'rating': 'Punteggio 3,0 su 5',
#    'no_likes': '4',
#    'date': 'Scritta in data 17 agosto 2016',
#    'title': 'Poco da vedere',
#    'text': "Situato sulla SS12, all'altezza dell'abitato di Marco, nel comune di Rovereto. In zona pianeggiante, non è niente altro che un cospicuo numero di massi di varie dimensioni, caduti in epoca preistorica e che sembra abbiano condizionato il corso dell'Adige. Celebre più per la citazione dantesca, nell'Opera Somma."}],
#  'La Pizia Pizza & Ristò': [{'name': 'PaoloMac78',
#    'no_reviews': '2',
#    'rating': '5',
#    'date': '6 novembre 2021',
#    'title': 'Ottima pizza a Marco',
#    'text': 'Da consigliare sicuramente per la pizza molto buona e con ingredienti di qualità.\nLocale semplice ma molto accogliente. Personale molto simpatico e gentile.\nPrezzi nella norma',
#    'likes': '1 \xa0'},
#   {'name': '635giampaolob',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '30 ottobre 2021',
#    'title': 'Pienamente soddisfatto',
#    'text': "Arrivato a mezz'ora dalla chiusura e senza aver prenotato ma tuttavia il servizio è stato cortese e impeccabile.\nPizza ottima, impasto eccellente.\nSicuramente da ritornare",
#    'likes': '1 \xa0'},
#   {'name': 'fabrizio_bosco_63',
#    'no_reviews': '4',
#    'rating': '5',
#    'date': '15 ottobre 2021',
#    'title': 'Pizza Top',
#    'text': 'Locale consigliato da un collega di lavoro, pizza veramente buona con ingredienti di primissima qualità; esperienza sicuramente da riprovare',
#    'likes': '1 \xa0'},
#   {'name': 'Giulia C',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '15 ottobre 2021',
#    'title': 'Una piacevolissima scoperta',
#    'text': 'Io e mio marito volevamo dedicarci una serata senza figli e, viste le recensioni, abbiamo deciso di provare questa pizzeria! Non avremmo potuto fare scelta migliore! Pizza fantastica, morbida ma croccante allo stesso tempo, e soprattutto leggerissima e super digeribile!! Una vera delizia! Alla fine...della serata abbiamo fatto 2 chiacchiere con la proprietaria, molto simpatica e disponibile!\nCi torneremo sicuramente!!Più',
#    'likes': '1 \xa0'},
#   {'name': 'G3227MZdanielap',
#    'no_reviews': '1',
#    'rating': '4',
#    'date': '9 ottobre 2021',
#    'title': 'Serata con amici',
#    'text': 'Panini squisiti con pasta di pizza per tutti i palati e pizza degna di tale nome. Menù vario, sfizioserie e fast food. Personale giovane e dinamico.',
#    'likes': '1 \xa0'},
#   {'name': 'GAPwow',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '8 ottobre 2021',
#    'title': 'La pizia migliore!',
#    'text': 'Pranzo gustoso ed eccezionale! Siamo molto soddisfatte, un esperienza culinaria fantastica! Il servizio eccellente 😍',
#    'likes': '1 \xa0'},
#   {'name': 'Manu899',
#    'no_reviews': '6',
#    'rating': '4',
#    'date': '28 settembre 2021',
#    'title': 'Pizza integrale ottima, senza glutine con base',
#    'text': 'Ho sfruttato la posizione in vicinanza dell’imbocco autostradale quest’estate per cenare in questo piccolo laboratorio specializzato in pizze gourmet. Si trova in pieno centro di questa piccola cittadina chiamata Marco. L’ambiente è molto giovane e il personale è gentile e disponibile. I miei famigliari che...hanno potuto provare l’impasto integrale e la scrocchiarella ne sono rimasti piacevolmente colpiti. Io invece ho preso una pizza senza glutine ma con dispiacere ho constatato che si trattava di una base precotta. Gli ingredienti sopra erano comunque di qualità ma la base non era nulla di speciale.Più',
#    'likes': '1 \xa0'},
#   {'name': 'Francesco0317',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '26 settembre 2021',
#    'title': 'Pizza a pranzo',
#    'text': "Siamo stati oggi a pranzo in compagnia di amici. \nAbbiamo preso il piatto forte della casa, la pizza e devo dire che è veramente buona, curata sia nell'impasto che negli ingredienti di farcitura.\nConsigliatissima",
#    'likes': '1 \xa0'},
#   {'name': 'Claudiablanca',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '5 settembre 2021',
#    'title': 'ECCEZIONALE',
#    'text': "Avrei voluto scrivere un titolo più accattivante, ma ECCEZIONALE è a sola cosa che mi viene in mente. Abbiamo mangiato pizza e ci sono una serie di considerazioni da fare: si parte da una vasta scelta di diversi impasti disponibili, anche senza glutine (in tutto...5/6),si prosegue con un vastissimo ma non banale menu di pizze(spesso menù ampi portano a pizze che gira e rigira sono tutte uguali), gli ingredienti sono di prim'ordine per quanto riguarda affettati formaggi e pesce, fatti dalla loro cucina per quanto riguarda il resto. Ho preso semplicemente una vegetariana, la più buona che abbia mai mangiato in vita mia. Non zucchine melanzane Peperoni grigliati ma a dadini in forno, in più cavolo stufato, Spinaci, olive taggiasche e cipolla rossa. Abbiamo preso anche pizze più gorde, una con patate al forno stracchino e lardo e una con burrata mortadella e pistacchi. Pizze leggerissime, ben farcite, cornicione alveolato... PERFETTE. Menzione particolare alle artefici di tutto... Si, perche la pala e il fuoco lo gestiscono due ragazze giovani ma molto titolate a giudicare dai molteplici attestati appesi alle pareti....e dal capolavoro nel piatto! 45 euro in 3 per aver mangiato una pizza indimenticabile, se questa pizzeria fosse in zona Venezia (da dove veniamo) 30 euro a persona lì avremmo spesi tutti.Più",
#    'likes': '1 \xa0'},
#   {'name': 'danielazG1011HO',
#    'no_reviews': '1',
#    'rating': '4',
#    'date': '24 agosto 2021',
#    'title': 'Inaspettata',
#    'text': 'Dopo ore di coda in autostrada decidiamo di uscire e di fermarci nel primo posto.  Entriamo in una classica pizzeria, carina, ma nulla di particolare, che potesse far presagire la bontà della cucina. Ci accoglie una ragazza gentilissima e scopriamo, dopo aver mangiato, di essere...capitati per caso in un locale che consiglio vivamente.  Pizza molto buona. Insalatona Pizia grandiosa, servita con il pane appena sfornato (divino). Altri piatti abbondantissimi. Ottimo rapporto qualità/quantità/prezzo. Se passate da lì fermatevi: ne vale la pena.Più',
#    'likes': '1 \xa0'}],
#  'Viadante 20': [{'name': 'Stefania M',
#    'no_reviews': '2',
#    'rating': '2',
#    'date': '7 settembre 2020',
#    'title': 'Sconsigliato per la colazione',
#    'text': "Siamo stati qui per un cornetto e caffè e non ci è piaciuto: il cornetto era gommoso e pallido e la marmellata sapeva quasi di sapone. Non so dire com'è per l'aperitivo ma per la colazione non ci tornerei.",
#    'likes': ''},
#   {'name': 'g t',
#    'no_reviews': '4',
#    'rating': '3',
#    'date': '7 febbraio 2020',
#    'title': 'Aperitivo pre cena',
#    'text': 'Abbiamo approfittato di un tranquillo venerdì sera per consumare aperitivo quì; ill locale è molto carino e semplice; servizio nella norma e professionale.',
#    'likes': ''},
#   {'name': 'T386TLandreap',
#    'no_reviews': '3',
#    'rating': '4',
#    'date': '28 dicembre 2019',
#    'title': 'Ottimo ',
#    'text': 'Bellissimo locale personale gentile è qualificato prezzi onesti si mangia benissimo consigliato\n\n..........',
#    'likes': ''},
#   {'name': 'NicoLucarelli',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '14 settembre 2019',
#    'title': 'Piccola grande scoperta',
#    'text': "Eravamo in vacanza vicino a Rovereto e facendo un giro per il centro, arrivata sera abbiamo deciso di fermarci in questo posticino. Da fuori sembra più un posto da aperitivi e stuzzicheria.. Invece una volta che entri dentro e ti lasciano il menu hai l'imbarazzo...della scelta ed abbiamo preso antipasto e primo tipici ultrascuisiti.. Siamo rimasti veramente soddisfatti, personale gentilissimo e simpatico. Se dovessi ricapitare a Rovereto sarà il primo posto dove andare a cena o farmi un aperitivo. GrandiPiù",
#    'likes': ''},
#   {'name': 'GianlucaB-CristinaG',
#    'no_reviews': '1',
#    'rating': '4',
#    'date': '21 agosto 2019',
#    'title': 'Aperitivo',
#    'text': "Ottima scelta di vini per un aperitivo con amici. Bollicine o cocktail sarete soddisfatti. Stuzzichini o piatti più robusti da assaporare anche fuori all'aperto su via Dante.",
#    'likes': '31 \xa0'},
#   {'name': 'Maurizio C',
#    'no_reviews': '2',
#    'rating': '3',
#    'date': '13 giugno 2019',
#    'title': 'Più che un CAFÉ ',
#    'text': 'Non è un bar non è un ristorante è un locale dove si possono trovare piccole prelibatezze. Ottimi panini insalate e primo piatto del giorno. La mia bresaola su misticanza con formaggio e salsa dolce non mi ha entusiasmato ma era buona. Il posto è...stretto eil tavolo di fronte al bagno non è tanto bello ma ci di deve adattare.     Comunque ci si può andare sereni che qualcosa di interessante si trova sempre.Più',
#    'likes': '2 \xa0'},
#   {'name': 'FRANCESCAPAOLO13',
#    'no_reviews': '5',
#    'rating': '5',
#    'date': '16 gennaio 2019',
#    'title': 'bistrot',
#    'text': 'Locale piccolo e curato, I gestori son molto competenti con ampia scelta di vini. Ottima anche la cucina, valido anche per le colazioni o per aperitivi',
#    'likes': ''},
#   {'name': 'Alessandra G',
#    'no_reviews': '4',
#    'rating': '4',
#    'date': '9 novembre 2018',
#    'title': 'Localino estroso.',
#    'text': "Oggi a pranzo non volendo abbuffarmi ho scelto questo locale per mangiare veloce. Localino piccolo ma molto carino, con pochi tavoli. Menu' diverso dal solito e con un piatto del 20 che ho capito che varia. Ho scelto un piatto di risotto ai carciofi, pomodori...secchi, robiola e noci buonissimo. Ci sono insalatone, panini, piade farcite e altro. Personale molto cordiale. AlessandraPiù",
#    'likes': '1 \xa0'},
#   {'name': 'Antonella D',
#    'no_reviews': '4',
#    'rating': '5',
#    'date': '22 ottobre 2018',
#    'title': 'Pranzi veloci ed ottimi',
#    'text': 'Piatti ottimi, materie di prima qualità e servizio impeccabile! Buonissime le focacce gourmet ed i piatti del venti (couscous, insalate di farro).',
#    'likes': '1 \xa0'},
#   {'name': 'anna m',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '8 ottobre 2018',
#    'title': 'Buono',
#    'text': "Sono stata in questo locale più volte a fare aperitivo ed in un'occasione ho anche pranzato.\nTutto ottimo, dallo spritz fino ai piatti ordinati, servizio veloce e cordiale.\nUnica pecca sono i pochi tavolini all'interno.",
#    'likes': ''}],
#  'Museo Civico di Rovereto': [{'name': 'Emilio F',
#    'location': 'Monte Isola, Italia',
#    'no_reviews': '2 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 5 giugno 2021',
#    'title': 'Bel museo!',
#    'text': "Veramente un bel museo dove portare i bambini: monete antiche, pietre, animali.E' stato piacevole visitarlo insieme a tutta la famiglia. Con la Trentino Guest Card ricevuta tramite la prenotazione in albergo l'entrata è addirittura gratis per tutta la famiglia! Veramente un' ottima iniziativa."},
#   {'name': 'Imke1965',
#    'location': None,
#    'no_reviews': '61 contributi',
#    'rating': 'Punteggio 4,0 su 5',
#    'no_likes': '2',
#    'date': 'Scritta in data 26 gennaio 2020',
#    'title': 'Un museo per conoscere Rovereto e la sua storia',
#    'text': 'Piccolo museo ad entrata gratuita molto ben organizzato e allestito. Ci sono diverse postazioni interattive che permettono di conoscere meglio la storia e la città di Rovereto. Ne consiglio la visita anche a famiglie con bambini e bambine'},
#   {'name': 'Archibugio1',
#    'location': 'Rovereto, Italia',
#    'no_reviews': '106 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '1',
#    'date': 'Scritta in data 3 settembre 2019',
#    'title': 'Museo classico',
#    'text': "Un museo classico con alcune particolarità come l'esterno in cui, all'interno di un orto botanico troviamo un planetario in cui vengono proiettate rappresentazioni in tempo reale del cielo."},
#   {'name': 'Sara C',
#    'location': None,
#    'no_reviews': '2 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 8 agosto 2019',
#    'title': 'Bel museo',
# ...
#    'text': "Silenzio è la parola d'ordine all'intero degli spazi di questa storica biblioteca, completamente rinnovata e ampliata alcuni anni fa. Ci sono più piani e uno spazio riservato alla biblioteca dell'università di Trento (soprattutto con testi per la specializzazione in psicologia). C'è un ampio spazio dedicato ai bambini con allestimenti e giochi, una sala lettura con i quotidiani cartacei e almeno una trentina di riviste su diverse tematiche. Nella piano interrato c'è uno spazio dedicato alla fotocopisteria interna e un'enorme sala per studio. C'è poi uno spazio, meno accessibile e noto (riservato) dove ci sono conservati macchinari e testi che utilizzano i vecchi caratteri tipografici  (prodotti ancora oggi)."},
#   {'name': 'Alessandro S',
#    'location': 'Trento, Italia',
#    'no_reviews': '116 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 29 aprile 2018',
#    'title': 'La Cultura nel centro di Rovereto',
#    'text': "La biblioteca di Rovereto, situata nella piazzetta del Mart offre sicuramente un ottimo punto dove andare in cerca di cultura.La bibblioteca è molto ben fornita ed il personale è altamente qualificato e compoetente.Utilissima la possibilità di poter consultare gli archivi tramite pc per poter vedere subito se il volume che si sta cercando è disponibile e dove trovarlo.Entrando si respira subito un aria di sapere. Comodissima poi per studenti che hanno la necesità di un posto tranquillo dove studiare.E' disposta su due livelli. Nella parte sopra cioè dove c'è l'entrata ci ono i volumi dedicati alle giovani menti con un area dilettura appositamente studiata, una zona ristoro con macchinette automatiche e la zona delle riviste.Scendendo le scale invece si entra nella parte studiata per gli studenti.questa divisione permette a chi vuole stuiare di isolarsi dall'andirivieni di persone ed evitare istrazioni. Ottima biblioteca consigliata a tuttti."},
#   {'name': 'Malki Tzedek',
#    'location': 'Tel Aviv, Israele',
#    'no_reviews': '8.265 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '6',
#    'date': 'Scritta in data 14 aprile 2018',
#    'title': 'Arte, cultura e tipografia!',
#    'text': 'Ho visitato questa caratteristica biblioteca, intitolata al Tartarotti, che si estende in ampi spazi di lettura e di studio. All’ingresso c’è anche uno spazio dedicato interamente ai bambini, dove possono  leggere e giocare in assoluta sicurezza o intrattenersi con le iniziative che vengono organizzate. Il personale è gentilissimo e competente, ha risposto a tutte le mie richieste e curiosità, sono numerose le mostre che si tengono nel corso dell’intero anno. Ho avuto la fortuna di poter visitare anche una parte di questo gioiello, non sempre aperto al pubblico, infatti, in questa biblioteca, c’è una parte storica dove sono custoditi antichissimi tomi, finemente rilegati e, ben custoditi. Tesori che gli amanuensi hanno prodotto con le loro mani, con anni di straordinario lavoro. Nel sotto piano, invece un’altra bella sorpresa, antichi macchinari di stampa, ancora ben funzionati. Una cooperativa di non più giovani tipografi, tutti rigorosamente in pensione, si diletta ancora con queste stupende macchine, realizzando manifesti e iniziative grafiche per tutta la città. Un’eredità molto importante che non dovrebbe andare persa. Questa società di amanti della grafica hanno adottato come loro simbolo rappresentativo, un riccio, allegoria di umiltà e alacre lavoro. Grazie di cuore a Nicoletta, che con le sue preziose spiegazioni, mi ha condotto e fatto comprendere la realtà e la storia della sua biblioteca. Consigliatissima una visita.'},
#   {'name': 'Gloria M',
#    'location': None,
#    'no_reviews': '26 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 19 febbraio 2018',
#    'title': 'Ottima',
#    'text': 'Ottima biblioteca. Molto spazio a disposizione per studiare o lavorare. Personale disponibile, anche se non sempre molto educato. Spazio bar, spazio per bambini e sala riunioni.Molto ricca di libri'},
#   {'name': 'mariarita p',
#    'location': 'Milano, Italia',
#    'no_reviews': '25.837 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 11 dicembre 2017',
#    'title': 'Biblioteca bella e fornita',
#    'text': 'Ha ampi spazi per studiare o anch solo per sedersi, è pulita, ordinata, e con un patrimonio librario di tutto rispetto. Eravamo di passaggio a Rovereto, siamo entrati e ci ha colpito quanto è ben organizzata'},
#   {'name': 'René Q',
#    'location': 'Rovereto, Italia',
#    'no_reviews': '76 contributi',
#    'rating': 'Punteggio 5,0 su 5',
#    'no_likes': '0',
#    'date': 'Scritta in data 22 dicembre 2016',
#    'title': 'Cultura e mostre vanno a braccetto',
#    'text': "Ampi spazi di lettura, un locale dedicato ai bambini fino a 6 anni in cui possono leggere e giocare in assoluta tranquillità, numerose mostre che vengono fatte nel corso dell'anno. Oltre a libri, libri e ancora libri, compresi gli ebook."}],
#  'B&B Manu & Dige': [{'name': 'tondocibei',
#    'date': 'dic 2019',
#    'location': 'Treviso, Italia',
#    'no_reviews': '133',
#    'likes': '59',
#    'rating': '5',
#    'title': 'bellissima accoglienza',
#    'text': "L'accoglienza è stata piacevole e calda. Come tornare a casa dopo un viaggio. Carinissimi e gentilissimi i proprietari e dolcissima la piccola Nuka.. Camera con bagno privato curata nei minimi dettagli. Doccia ampia e pulizia impeccabile in tutti i luoghi. Colazione buonissima e ottima la loro compagnia. Grazie di tutto."},
#   {'name': 'paoloCapizzi',
#    'date': 'nov 2019',
#    'location': 'Roma, Italia',
#    'no_reviews': '284',
#    'likes': '99',
#    'rating': '3',
#    'title': 'Silenzio e cordialità',
#    'text': "Casa abitata che mette a disposizione delle stanze... Poche, pulite, con bagno ma senza TV. Wi fi presente, buona la connessione. Zona isolata e quindi silenziosa. Un paio di km dal centro  Buona la colazione, specie il caffè  Proprietari discreti, ma nello stesso tempo gentili e accoglienti Alzerei un pochino la temperatura sia dell'acqua che del termosifone.... Quando piove e fa freddo...."},
#   {'name': 'Francesco',
#    'date': 'lug 2019',
#    'location': 'Bivona, Italia',
#    'no_reviews': '71',
#    'likes': '49',
#    'rating': '4',
#    'title': 'Soddisfatto ',
#    'text': 'Camera (con bagno in camera) molto confortevole.  Colazione molto varia ed abbondante. A circa 15 minuti a piedi dalla stazione dei treni e dal centro della città.  I Proprietari gentili e molto discreti. '},
#   {'name': 'ilarya91',
#    'date': 'dic 2018',
#    'location': 'Verona, Italia',
#    'no_reviews': '7',
#    'likes': '1',
#    'rating': '5',
#    'title': 'Gran bel b&b',
#    'text': 'Una notte a Rovereto per vedere i mercatini di Natale! Gran bel b&b con persone disponibili e gentili! Una buonissima colazione al mattino! Possibilità di portare i propri amici a quattro zampe (io ho portato i miei due cuccioli di beagle)'},
#   {'name': 'adecarli60',
#    'date': 'mag 2018',
#    'location': 'Rovereto, Italia',
#    'no_reviews': '1',
#    'likes': '2',
#    'rating': '1',
#    'title': 'Non andremo mai',
#    'text': 'Non andremo mai. I tentativi di ricevere una risposta sulla disponibilità sia la scorsa settimana a partire dal 10/05 (eravate pieni per la vicina adunata degli alpini e non sapevate come dirlo ? Overbooking ?) sono stati infruttuosi. Le faremo sapere.....ma non vi abbiamo più sentiti. Un nuovo tentativo 2 giorni fa, arriva il giro d’Italia, ho pensato, un bel week end lungo, ho penato....la mia famiglia ne sarà felice. Dopo due giorni di attesa della chiamata che non arriva ho prenotato all’Hotel Rovereto. Allo stesso costo. Meditate gente meditate. Compratevi una bella agenda per i contatti con i vostri futuri clienti. E non fossilizzate il business solo con clienti fidelizzati. Fidatevi. Siate aperti anche ai nuovi clienti. Tanti auguri per la vostra attività.'}],
#  'Hotel Flora': [{'name': 'Santo Di Cartici',
#    'date': 'giu 2018',
#    'location': 'Toscana, Italia',
#    'no_reviews': '353',
#    'likes': '96',
#    'rating': '3',
#    'title': 'per una sosta di passaggio',
#    'text': "Durante un viaggio di vacanza ci siamo fermati in questo hotel solo per una notte, e lo abbiamo trovato comodo e pulito, d'altra parte non avevamo la pretesa di fermarci per una vacanza. La colazione è stata un pò sbrigativa, ma comunque nella media (si trova di peggio)"},
#   {'name': 'Emiliano A',
#    'date': 'nov 2017',
#    'location': 'Roma, Italia',
#    'no_reviews': '45',
#    'likes': '16',
#    'rating': '4',
#    'title': 'Per una notte di riposo',
#    'text': "Ci sono arrivato quasi per caso perché l'area di sosta dei camper lì vicino era in totale disuso. Lungo la strada ho trovato questo Hotel, con un parcheggio che poteva contenere i 6 metri del mio mezzo. Prezzo ottimo, 50 euro per una singola ad Agosto. Ho anche cenato lì perché ero stanco, cucina non eccelsa, ma dignitosa, così come il prezzo, solo 10 euro! Oltretutto ho cenato insieme al proprietario, che trovo sia una persona piacevole. La stanza super accogliente, letto comodissimo e bagno enorme, con doccia idromassaggio. Dalla finestra bel panorama sui monti. Non so se consigliarlo per un soggiorno più lungo, ma buono per una visita a Rovereto di un paio di giorni, anche in famiglia."},
#   {'name': 'xxx',
#    'date': 'giu 2017',
#    'location': 'Padova, Italia',
#    'no_reviews': '64',
#    'likes': '43',
#    'rating': '1',
#    'title': 'Non è quello che sembra ',
#    'text': 'Locale pubblicizzato, con molti servizi : palestra , centro benessere , ristorante , bar ecc . Nonostante siamo presenti, non sono utilizzabili perché non vi è il personale che fanno funzionare i locali . In pratica nell hotel funzionano solo le stanze . A mio avviso usato anche come " motel " . Se è per una notte può andare bene, ma non di più . Sconsigliato .'},
#   {'name': 'Paolo B',
#    'date': 'mag 2017',
#    'location': 'Reggio Emilia, Italia',
#    'no_reviews': '45',
#    'likes': '23',
#    'rating': '5',
#    'title': 'Una notte tranquilla',
#    'text': "Ho selezionato questo hotel per la notte tra il 29/04 e il 30/04 perchè volevo visitare Rovereto. Il museo della guerra nel castello di Rovereto, la campana dei caduti, il sacrario militare e ovviamente il centro. La posizione è ottimale all'ingresso della città, pulito e il personale molto cordiale, ottima anche la colazione la mattina a buffet. Dalla finestra della camera si vedeva il sacrario militare molto bene, mentre la campana dei caduti un po nascosta dalla vegetazione. Tutte le sere alle 21:30 suona in memoria di tutti i caduti di tutte le guerre del mondo. Per me... Hotel promosso a pieni voti."},
#   {'name': 'Ronchiz',
#    'date': 'apr 2017',
#    'location': None,
#    'no_reviews': '3',
#    'rating': '2',
#    'title': 'Bella struttura ma il resto maluccio',
#    'text': "La struttura acetabile con camere piuttosto spaziose. Purtroppo il cibo non è buonisimo(vi sconsigliamo le patate) e sono ecesivi sul fatto di rimanere in silenzio durante i pasti. Positivo il fatto che c'è canale 5 e ho potuto vedere la partita. FORZA JUVE!"}],
#  'Caffe Bontadi': [{'name': 'LucaChiaraD',
#    'no_reviews': '1',
#    'rating': '3',
#    'date': '25 agosto 2021',
#    'title': 'Aperitivo passabile',
#    'text': 'Fermati per un aperitivo ai tavolini all’esterno . Spritz nella media con degli stuzzichini (che vedete in foto) davvero minimali e nemmeno di grande qualità. Prezzi nella media della città.',
#    'likes': '22 \xa0'},
#   {'name': 'Paola Q',
#    'no_reviews': '1',
#    'rating': '2',
#    'date': '21 agosto 2021',
#    'title': 'VERGOGNOSO!!!!!',
#    'text': 'Chiedo un goccio d\'acqua per la mia bimba dopo aver preso due caffè e mi dicono che la danno solo in "mono porzione"!!!!!!',
#    'likes': ''},
#   {'name': 'elecO2193GD',
#    'no_reviews': '3',
#    'rating': '5',
#    'date': '7 agosto 2021',
#    'title': 'Ottimo caffè ',
#    'text': 'Antico caffè ed antica torrefazione artigianale dal 1790.\nOttimo il caffè;  locale molto bello ; personale gentilissimo . È bello vedere persone che si dedicano con passione al proprio lavoro.\nLo consiglio vivamente! !!👍',
#    'likes': '1 \xa0'},
#   {'name': 'Terzonitrox',
#    'no_reviews': '1',
#    'rating': '5',
#    'date': '23 maggio 2021',
#    'title': 'Pranzo di passaggio.',
#    'text': 'Volevamo pranzare con qualcosa di semplice e veloce. Siamo rimasti molto soddisfatti sia della cura nella preparazione, che le materie prime di primissima qualità utilizzate.\nPersonale molto preparato e gentilissimo che ha risolto con professionalità un piccolo disguido.\nConsiglio moltissimo.',
#    'likes': ''},
#   {'name': '509remoc',
#    'no_reviews': '4',
#    'rating': '1',
#    'date': '24 gennaio 2021',
#    'title': 'Locale carino ma servizio inaccettabile ',
#    'text': 'Locale carino ma servizio non adeguato al prezzo. 2 caffè a 2,40. Quando abbiamo chiesto un goccino di acqua dalla spina ci è stato risposto che non è possibile dato il periodo e che venivano vendute solamente le acque in bottiglia. Imbarazzante. Trovare una scusa...migliore per dire che non volete dare l’ acqua della spina ma guadagnarci sarebbe meglio.Più',
#    'likes': '4 \xa0'},
#   {'name': 'mattiapB6490WY',
#    'no_reviews': '1',
#    'rating': '1',
#    'date': '22 novembre 2020',
#    'title': 'Imbarazzante',
#    'text': 'Posto stupendo per fare colazione. \n2.50 euro per un cannolo siciliano\nMangiato in un morso. \nImbarazzante.',
#    'likes': '3 \xa0'},
#   {'name': 'Manu899',
#    'no_reviews': '6',
#    'rating': '4',
#    'date': '21 novembre 2020',
#    'title': 'Miglior bar di Rovereto ',
#    'text': 'A mio parere il miglior bar di Rovereto. La posizione è da urlo essendo collocato in una delle più belle piazze della città. Il personale è gentilissimo ed il caffè è uno dei più buoni mai provati( la torrefazione è a pochi chilometri di distanza)....Aspetto non secondario il fatto che ci sia sempre qualche opzione senza glutine da accompagnare al caffè( io consiglio la buonissima torta caprese o dei biscottini sempre presenti).Più',
#    'likes': '1 \xa0'},
#   {'name': '315emanuelal',
#    'no_reviews': '8',
#    'rating': '1',
#    'date': '20 agosto 2020',
#    'title': 'Da turisti....provato ma non ci torneremo di sicuro',
#    'text': 'Dopo una passeggiata da turisti nel centro storico decidiamo di rilassarci sui tavolini in piazza di questo locale che a vederlo ti attira:\nChiediamo un alcolico e 1 analcolico (tra l’altro pessimo, sembrava da cartoccio) e una lemonsoda . Ora di aperitivi....nemmeno una patatina, mentre...ad altri tavoli almeno quelle le avevano portate!!! 6+5+ ...€ non ricordo la lamonsoda!! Siamo rimasti allibiti, la prossima volta sceglieremo altro posto!!!! Forse siamo noi abituati ad aperitivi con tavole ricche di ogni....però ci vuole davvero poco....Più',
#    'likes': '4 \xa0'},
#   {'name': 'NickyLittle87',
#    'no_reviews': '1',
#    'rating': '4',
#    'date': '28 luglio 2020',
#    'title': 'Tutto ottimo',
#    'text': "Locale penso storico della cittadina, con fila da fare per entrarci durante il weekend vista la proposta dolciaria proposta.\nMerenda molto molto piacevole, sia per l'atmosfera che per i dolci provati.\nFavorevolmente sorpresi dall'enorme possibilità di scelta.\nServizio veloce nonostante il pienone del sabato.\nPer...gusto personale direi che si potrebbe un po' ammodernare per illuminarlo un po' di più.\nDecisamente fuori porta rispetto a casa, ma decisamente da tornarci quando ci si troverà di nuovo da queste parti.Più",
#    'likes': '2 \xa0'},
#   {'name': 'pippozanella',
#    'no_reviews': '7',
#    'rating': '5',
#    'date': '6 luglio 2020',
#    'title': "Un'ottima pausa caffè",
#    'text': "Dopo una breve passeggiata per il centro storico ci siamo fermati in questo splendido caffè per una piccola pausa. \n\nBontadi è una delle antiche torrefazioni italiane, poco distante troverete anche un museo fatto su misura e all'interno del bar potete acquistare del caffè proveniente da...svariate parti del mondo e dal profumo inebriante.Più",
#    'likes': '2 \xa0'}]}

# %% [markdown]
# # Ex 4
#
# The following iterative sequence is defined for the set of positive integers:
#
# <br><center> n → n/2 (n is even)
#
# <center>n → 3n + 1 (n is odd)
#
# <br>Using the rule above and starting with 13, we generate the following sequence:
#
# <br><center> 13 → 40 → 20 → 10 → 5 → 16 → 8 → 4 → 2 → 1
#
#
# <br>It can be seen that this sequence (starting at 13 and finishing at 1) contains 10 terms. Although it has not been proved yet (Collatz Problem), it is thought that all starting numbers finish at 1.
#
# Which starting number, under one million, produces the longest chain?
#
# NOTE: Once the chain starts the terms are allowed to go above one million.

# %%
def even(n):
    return int(n / 2)

def odd(n):
    return 3 * n + 1

def check_number(n):
    if n % 2 == 0:
        return "even"
    return "odd"

def generate_seq(starting_number):
    if starting_number == 0:
        return [starting_number]
    else:
        current_number = starting_number
        sequence = [starting_number]
        while current_number != 1: 
            typology = check_number(current_number)
            if typology == "even": 
                next_num = even(current_number)
            else: 
                next_num = odd(current_number)
            sequence.append(next_num)
            current_number = next_num
    return sequence, len(sequence)

# %%
longest = [0,0]
for number in range(1,1000000):
    sequence, length = generate_seq(number)
    if length > longest[1]:
        longest[0] = number
        longest[1] = length

# %%
print(f'{longest[0]} produces the longest chain (length equals to {longest[1]})')
# Out:
# 837799 produces the longest chain (length equals to 525)
