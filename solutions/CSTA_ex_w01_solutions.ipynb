# %% [markdown]
# # Warm-up exercise
#
# Import a text file into a Jupyter Notebook and store it as a string in a variable of your choice. Strings are iterables, so using a for loop to iterate over the string you just stored, and using an if/else conditional statement print only those characters that are digits (i.e.: numbers). Yes, you are correct, we have not talked about conditional stamentes yet, but it should not be too difficult to find something about it online. If you want to go a bit further, "save" the digits in a list, instead of printing them out. A couple of magic words are: "isdigit" (a method of the the data type string), "append" (a method of the data type list).

# %%
file = open("../data/mystery.txt", encoding="utf-8-sig")
text = file.read()
print(f"type of text is: {type(text)}")

numbers_in_text = []
for char in text:
    if char.isdigit():
        print(char)
        numbers_in_text.append(char)

# %%
print(numbers_in_text)

# %% [markdown]
# # Ex 1
#
# Open any text file with "open()" (you can donwload one using the Gutenberg Project webpage or choose one from those provided) and store the "IO.TextIOWrapper" object in variable.
#
# Using a for loop to iterate over it, find out which type of items it is "made of". Next, store the iteration as a list in a variable.
#
# Take a look at the list and try to obtain the same object by using the split() method of the string obtained thanks to the .read() method of the "IO.TextIOWrapper".

# %%
# open the file and store the output object in a variable

file = open("../data/emma.txt" , encoding = "utf-8-sig")
print("Type of text: ", type(file))

# Using a for loop to iterate over it, find out which type of items it is "made of".
# Next, store the iteration as a list in a variable.

text = []

for i in file:
    print(type(i))
    text.append(i)
    
# Try to obtain the same object by using the split() method of the string
# obtained thanks to the .read() method of the "IO.TextIOWrapper".

text_2 = open("../data/emma.txt", encoding="utf-8-sig").read().split("\n")

# %%
print(f"length of text: {len(text)}\nlength of text_2: {len(text_2)}")

# %% [markdown]
# # Ex 2
#
# Define a function that takes 3 arguments:
#
#  - a list of strings
#  - an integer
#  - a path
#
# The function will do 2 things:
#   - it return a list that contains only the strings that are longer than the integer
#   - it writes a text file (specified in as the third argument) that contains the strings separated by a new line.

# %%
def myfunction(strings, number, path):
    l = []
    file = open(path,"w")
    for el in strings:
        if len(el) > number:
            l.append(el)
        file.write(el + "\n")
    file.close()
    return l

# %%
a = ["engine",
    "crime",
    "scandal",
    "affair",
    "refund",
    "faint",
    "safety",
    "rope",
    "lane",
    "dough",
    "predator",
    "hope",
    "progressive",
    "world",
    "computer",
    "insurance",
    "lazy",
    "argument",
    "native",
    "contain"]

myfunction(a, 5, "C://Users/Daniel/Desktop/myfile.txt")

# %% [markdown]
# # Ex 3
#
# Define a function that takes a path to a text file as argument. Tokenize it and store in a list all the tokens that begins with a vowel. Return a dictionary that contains the frequencies of the tokens in the list.

# %% [markdown]
# ### Solution n.1 (using split method)

# %%
import string 
vowels = "AEIOUaeiou"

def freq_1(path):
    file = open(path, encoding="utf-8-sig")
    text = file.read().split()
    l = []
    
    for el in text:
        tokens = el.split()
        for tok in tokens:
            if tok[0] in vowels:
                #removing punctuation
                for char in tok:
                    if char in string.punctuation:
                        tok = tok.replace(char,"")
                l.append(tok.lower())
    
    # calculating frequencies
    d = {}
    for el in l: 
        if el in d:
            d[el] += 1
        else:
            d[el] = 1
    
    return sorted(d.items(), key = lambda x:x[1], reverse=True)

# %%
freq_1("../data/emma.txt")

# %% [markdown]
# ### Solution n.2 (using nltk library)

# %%
import nltk
import string

def freq_2(path):
    file = open(path, encoding="utf-8-sig")
    text = file.read()
    
    tokens = nltk.word_tokenize(text.lower())
    cleaned_tokens = []
    
    for tok in tokens:
        for char in tok:
            if char in string.punctuation:
                tok = tok.replace(char,"")
                cleaned_tokens.append(tok)
    
    # calculating frequencies
    d = {}
    for el in cleaned_tokens: 
        if el in d:
            d[el] += 1
        else:
            d[el] = 1
    
    return sorted(d.items(), key = lambda x:x[1], reverse=True)

# %%
freq_2("../data/emma.txt")

# %% [markdown]
# # Ex 4
#
# As I said multiple times in class, we want to learn how to solve problems with code, and not just how to use some pre-packed functions or modules. In this exercise you are required to solve a procedural problem that guitar builders have solved a long time ago: where to place the metal pieces on a neck, also called **frets**, in order to obtain the right note when the instrument is played. In the case of guitars, the note position is fixed (in violins, for example, the player decides where to press the string on the neck). The average lenght of the strings on a guitar is called "diapason". We can obtain the distance between the beginning of the diapason (fret nr. zero or nut) and first fret by dividing the diapson by the constant **17.817**.
#
# The guitar that you see in the picture has a diapson of 647 cm (or 25 and 1/2 inches); as a consenquence the distance between the nut and the first fret is `36.31363304708986` (you can try this yourself in a cell using the `/` operator). In order to obtain the distance between the 1st and the 2nd fret we have to subtract the previous number that we have just obtained from the diapason, to obtain a *new* diapason of `610.6863669529101`. If we divide this number by 17.817 again, we obtain the distance between the 1st fret and the 2nd fret. That will be the position of the first fret.
#
# ![title](../img/guitar_ex.png)
#
# Define a function that takes as input two integers: a number representing the diapason of an instrument, and a number of frets (tipically guitars have between 20 to 24 frets). The output will be a list of tuples where the first item will be the position of the fret and the second item the distance. Something like
#
# `
# [(1, 36.31363304708986),
#  (2, 34.27548784604087),
#  (3, 32.351735932360626),
#  ...
#  (18, 13.602124694252558),
#  (19, 12.838689509078144),
#  (20, 12.118103018138134)]
# `
#
# The solution should not require more than 10 lines of code (depending on your style), but I strongly believe that you can solve the problem by using what you know at present, your brain, and a certain number of google searches. Some advice: do not search for a solution, but produce one, if you want to learn something.
#
# >NB: in order to solve the exercise you will probably need to use the `range()` method. If it is used with two integers as input, like in `range(1,20)`, it returns an iterable object that contains all the integers from 1 to 20 (excluded 20). Try to execute the following code to test the method:
#
#     `for i in range(1,20):
#     print(i)`
# >The solution is a variation of a counter updating strategy (remember the `+=` operator?) and of list appending. You will probably encounter the error message `TypeError: append() takes exactly one argument (2 given)`. That is because if you want to append a tuple, you need to use the right parantheses.

# %%
def fret_calculator(diapason, nr_frets):
    l = []
    for i in range(1,nr_frets+1):
        fret = diapason / 17.817
        diapason -= fret
        l.append(tuple((i, fret)))
    return l

fret_calculator(647,20)
