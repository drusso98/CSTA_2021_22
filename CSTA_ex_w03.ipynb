# %% [markdown]
# # Ex 1
#
# The <em>emails.txt</em> file is a list of 500 email addresses.
# 1. Return a list that contains all the addresses that starts with "s" and ends with ".com"
#
# 2. How many users have a Gmail account (xxx@gmail.xxx)? Store the addresses in a list.
#
# 3. According to Room 20 directives, an email address is valid if and only if it follows these rules:
#     - the username only contains alphanumeric characters
#     - the username might contain "-" and "."
#     - username and domain are separated by the @ symbol
#     - the domain name (gmail, hotmail etc.) only contains alpha characters
#     - domain name and domain are separated by "." symbol (gmail.com, yahoo.org etc.)
#     - the domain name (com, org etc.) only contains alpha characters
#
#     Write a boolean function that takes an email address as input and returns True (valid) or False (not valid). Use this function to check all the addresses and store valid and not valid ones in two different lists.
#
# 4. Room 20 directives imposes that all the email addresses with a domain name different from "gmail" must be converted into a "studenti.unitn" account. Write a function that takes a list of valid addresses as input and returns a list of tuples "(old_mail,new_mail)". Remember to save the new list in a text file.

# %% [markdown]
# # Ex 2
#
# The <em>amy.cha</em> file in the data folder contains an annotated transcription of a dialogue between a mother and her child. Lines that start with \*CHI or \*MOT refers to the speech transcript, the others comprises extra information previously manually marked about it. Suppose you are asked to extract the raw conversation between subjects and to make the text more readable for a person who doesn't know the annotation. There are two way to fullfil this request: manually select and modify all the proper lines, or use regular expressions. The second option seems more reasonable, especially with long text files.
#
# Thus, create a function that takes two arguments:
# 1. the path of the annotated file;
# 2. path of a new text file.
#
# The function must:
# - store in a list all the lines that start with <b>\*CHI</b> or <b>\*MOT</b>
# - substitute <b>\*CHI</b> or <b>\*MOT</b> with <b>\*Target_Child</b> and <b>\*Mother</b> respectively.
# - recreate the same file with the corrected lines.
# - return the list of all the lines that start with <b>\*CHI</b> or <b>\*MOT</b>

# %% [markdown]
# # Ex 3
#
# If we list all the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6 and 9. The sum of these multiples is 23.
#
# Find the sum of all the multiples of 3 or 5 below 1000.

# %% [markdown]
# # Ex 4
#
# 2<sup>15</sup> = 32768 and the sum of its digits is 3 + 2 + 7 + 6 + 8 = 26.
#
# What is the sum of the digits of the number 2<sup>1000</sup>?
