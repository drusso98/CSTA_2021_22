# %% [markdown]
# # Ex. 1 - Bag of Words (BoW)
#
# A Bag of Words (BoW) is a representation of text that describes the occurrence of words within a document. We just keep track of word counts and disregard the grammatical details and the word order. It is called a “bag” of words because any information about the order or structure of words in the document is discarded. The model is only concerned with whether known words occur in the document, not where in the document.
#
# <img src="https://miro.medium.com/max/661/1*3K9GIOVLNu0cRvQap_KaRg.png" width=500 height=300 />
#
# For example, the BoW of
#
# ```python
# "John likes to watch movies. Mary likes movies too. Mary also likes to watch football games. Bill doesn't!"
# ```
# will be
#
# ```python
# [2 1 1 1 1 1 1 1 3 2 2 2]
# ```
#
# Start from this example and try to obtain the same result. Use Stanza for the tokenization process and numpy for the creation of the BoW.

# %% [markdown]
# # Ex 2 - Features representation
#
# In NLP and ML text representation is crucial. Sometimes it may be useful to analyse specific aspects of a text so a word-based representation may no longer be sufficient. Thus, it is necessary to create a text representation based on specific features. In machine learning and pattern recognition, a feature is an individual measurable property or characteristic of a phenomenon. In NLP there are several features that can be extracted, depending on the task that is being performed. Read [this article](https://medium.com/swlh/nlp-all-them-features-every-feature-that-can-be-extracted-from-text-7032c0c87dee) to find out more.
#
# Modify the previous exercise in order to obtain a text representation based on the following features: lemmas and POS tagging.

# %% [markdown]
# # Ex 3 - Document-term matrix
#
# A document-term matrix is a mathematical matrix that describes the frequency of terms that occur in a collection of documents. In a document-term matrix, rows correspond to documents in the collection and columns correspond to terms [[1]](https://en.wikipedia.org/wiki/Document-term_matrix). Each value (typically) contains the number of appearances of that term in that document. This type of representation can be useful in tasks such as topic modeling.
#
# In the documents.txt file (data folder) you can find a collection of documents (each line a document, whose information - title and text - is separated by a semicolon): use it to build your Document-term matrix. Remember to remove stopwords and punctuation. Use pandas to display the result.

# %% [markdown]
# ## EX 4
#
# Compute the cosine similarity between all possible pairs of documents and save the values in a matrix. Which pair has the lowest value? Which has the highest?
#
# To calculate cosine similarity, you can either write your own function or use the sklearn module.
